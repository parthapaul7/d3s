# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output/Li.csv')
df.head()
# Out:
#    Frame  Scale  a_length  D3s_Energy  D3_Energy
# 0      0   0.70  3.033565   -0.000946  -0.000943
# 1      1   0.75  3.250249   -0.000671  -0.000671
# 2      2   0.80  3.466932   -0.000548  -0.000547
# 3      3   0.85  3.683615   -0.000539  -0.000538
# 4      4   0.90  3.900298   -0.000627  -0.000627

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['a_length']*1.73,df['D3s_Energy']*27.2, label='D3S Energy')
plt.plot(df['a_length']*1.73,df['D3_Energy']*27.2, label='D3 Energy')
# plt.plot(df['cell_length'],df['E-dispersion'])
plt.legend()
plt.show()
